// %% [markdown]
// # AWS SDK for Kotlin - Bedrock Converse API Example
// This notebook uses [AWS SDK for Kotlin](https://github.com/awslabs/aws-sdk-kotlin/) to implement the basic Bedrock Converse API operations
// - `converse`
// - `converseStream`
// - `converse` with `toolConfig` implementation
//
// Bedrock Converse API is AWS's service that provides a unified interface to interact with various AI language models for building conversational applications.
//
// More examples can be found on [official sample repository](https://github.com/awsdocs/aws-doc-sdk-examples/tree/main/kotlin).
// Free feel to contribute to add more use cases.

// %% [markdown]
// ## Install dependencies

// %%
// show kernel version
"""
Kotlin Jupyter kernel version: ${notebook.kernelVersion} (Update in Settings > Tools > Kotlin Notebooks > Kernel version)
Java Runtime Environment version: ${notebook.jreInfo.javaVersion}
"""
// Out:
// Kotlin Jupyter kernel version: 0.15.2.706.dev1 (Update in Settings > Tools > Kotlin Notebooks > Kernel version)
// Java Runtime Environment version: 21

// %%
%trackClasspath on
USE {
    repositories {
        mavenCentral()
    }
    dependencies {
        implementation("aws.sdk.kotlin:bedrockruntime-jvm:1.4.11")
        implementation("org.jetbrains.kotlinx:dataframe:0.15.0")

    }
    import(
        "aws.sdk.kotlin.services.bedrockruntime.*",
        "kotlinx.coroutines.runBlocking",
        "org.jetbrains.kotlinx.dataframe.*"
    )
}
// Out:
// 81 new paths were added to classpath:
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/sdk/kotlin/aws-config-jvm/1.4.11/aws-config-jvm-1.4.11.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/sdk/kotlin/aws-core-jvm/1.4.11/aws-core-jvm-1.4.11.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/sdk/kotlin/aws-endpoint-jvm/1.4.11/aws-endpoint-jvm-1.4.11.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/sdk/kotlin/aws-http-jvm/1.4.11/aws-http-jvm-1.4.11.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/sdk/kotlin/bedrockruntime-jvm/1.4.11/bedrockruntime-jvm-1.4.11.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-credentials-jvm/1.4.2/aws-credentials-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-event-stream-jvm/1.4.2/aws-event-stream-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-json-protocols-jvm/1.4.2/aws-json-protocols-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-protocol-core-jvm/1.4.2/aws-protocol-core-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-signing-common-jvm/1.4.2/aws-signing-common-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-signing-default-jvm/1.4.2/aws-signing-default-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/aws-xml-protocols-jvm/1.4.2/aws-xml-protocols-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-auth-api-jvm/1.4.2/http-auth-api-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-auth-aws-jvm/1.4.2/http-auth-aws-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-auth-jvm/1.4.2/http-auth-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-client-engine-default-jvm/1.4.2/http-client-engine-default-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-client-engine-okhttp-jvm/1.4.2/http-client-engine-okhttp-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-client-jvm/1.4.2/http-client-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/http-jvm/1.4.2/http-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/identity-api-jvm/1.4.2/identity-api-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/logging-slf4j2-jvm/1.4.2/logging-slf4j2-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/runtime-core-jvm/1.4.2/runtime-core-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/serde-form-url-jvm/1.4.2/serde-form-url-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/serde-json-jvm/1.4.2/serde-json-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/serde-jvm/1.4.2/serde-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/serde-xml-jvm/1.4.2/serde-xml-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/smithy-client-jvm/1.4.2/smithy-client-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/telemetry-api-jvm/1.4.2/telemetry-api-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/aws/smithy/kotlin/telemetry-defaults-jvm/1.4.2/telemetry-defaults-jvm-1.4.2.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/ch/randelshofer/fastdoubleparser/2.0.1/fastdoubleparser-2.0.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/fasterxml/jackson/core/jackson-annotations/2.18.0/jackson-annotations-2.18.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/fasterxml/jackson/core/jackson-core/2.18.0/jackson-core-2.18.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/fasterxml/jackson/core/jackson-databind/2.18.0/jackson-databind-2.18.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/fasterxml/jackson/datatype/jackson-datatype-jsr310/2.18.0/jackson-datatype-jsr310-2.18.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/github/ben-manes/caffeine/caffeine/2.9.3/caffeine-2.9.3-all.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/github/virtuald/curvesapi/1.08/curvesapi-1.08.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/github/waffle/waffle-jna/3.3.0/waffle-jna-3.3.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/google/flatbuffers/flatbuffers-java/24.3.25/flatbuffers-java-24.3.25.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/squareup/kotlinpoet-jvm/1.18.1/kotlinpoet-jvm-1.18.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/squareup/okhttp3/okhttp-coroutines/5.0.0-alpha.14/okhttp-coroutines-5.0.0-alpha.14.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/squareup/okhttp3/okhttp/5.0.0-alpha.14/okhttp-5.0.0-alpha.14.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/squareup/okio/okio-jvm/3.9.1/okio-jvm-3.9.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/com/zaxxer/SparseBitSet/1.3/SparseBitSet-1.3.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/commons-codec/commons-codec/1.17.1/commons-codec-1.17.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/commons-io/commons-io/2.18.0/commons-io-2.18.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/io/github/oshai/kotlin-logging-jvm/7.0.3/kotlin-logging-jvm-7.0.3.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/net/java/dev/jna/jna-platform/5.13.0/jna-platform-5.13.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/net/java/dev/jna/jna/5.13.0/jna-5.13.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/arrow/arrow-format/18.1.0/arrow-format-18.1.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/arrow/arrow-memory-core/18.1.0/arrow-memory-core-18.1.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/arrow/arrow-memory-unsafe/18.1.0/arrow-memory-unsafe-18.1.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/arrow/arrow-vector/18.1.0/arrow-vector-18.1.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/commons/commons-collections4/4.4/commons-collections4-4.4.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/commons/commons-compress/1.27.1/commons-compress-1.27.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/commons/commons-csv/1.12.0/commons-csv-1.12.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/commons/commons-lang3/3.16.0/commons-lang3-3.16.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/commons/commons-math3/3.6.1/commons-math3-3.6.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/logging/log4j/log4j-api/2.23.1/log4j-api-2.23.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/poi/poi-ooxml-lite/5.3.0/poi-ooxml-lite-5.3.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/poi/poi-ooxml/5.3.0/poi-ooxml-5.3.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/poi/poi/5.3.0/poi-5.3.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/apache/xmlbeans/xmlbeans/5.2.1/xmlbeans-5.2.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/checkerframework/checker-qual/3.32.0/checker-qual-3.32.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/annotations/23.0.0/annotations-23.0.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlin/kotlin-reflect/2.0.20/kotlin-reflect-2.0.20.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlin/kotlin-stdlib-jdk7/2.0.20/kotlin-stdlib-jdk7-2.0.20.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlin/kotlin-stdlib-jdk8/2.0.20/kotlin-stdlib-jdk8-2.0.20.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlin/kotlin-stdlib/2.1.0/kotlin-stdlib-2.1.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe-arrow/0.15.0/dataframe-arrow-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe-core/0.15.0/dataframe-core-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe-excel/0.15.0/dataframe-excel-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe-jdbc/0.15.0/dataframe-jdbc-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe-openapi/0.15.0/dataframe-openapi-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/dataframe/0.15.0/dataframe-0.15.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/kotlinx-coroutines-core-jvm/1.9.0/kotlinx-coroutines-core-jvm-1.9.0.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/kotlinx-datetime-jvm/0.6.1/kotlinx-datetime-jvm-0.6.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/kotlinx-serialization-core-jvm/1.7.1/kotlinx-serialization-core-jvm-1.7.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/jetbrains/kotlinx/kotlinx-serialization-json-jvm/1.7.1/kotlinx-serialization-json-jvm-1.7.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/mariadb/jdbc/mariadb-java-client/3.5.1/mariadb-java-client-3.5.1.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/slf4j/jcl-over-slf4j/2.0.7/jcl-over-slf4j-2.0.7.jar
// /Users/gaplo917/.jupyter_kotlin/maven_repository/.m2/.m2.cache/org/slf4j/slf4j-api/2.0.16/slf4j-api-2.0.16.jar
// Current classpath size: 91

// %% [markdown]
// ## Load AWS Access Key
// By default, there is a [credential chain provider](https://docs.aws.amazon.com/sdk-for-kotlin/latest/developer-guide/credential-providers.html) to look up your aws credentials from your environment.
//
// ⚠️ To remain portable and easier to understand, this example use ***custom credential provider*** that create `kotlinNotebookCredentialProvider` in `resources/aws.secret.json`

// %%
// Load aws.secret.json variables
%use @file[resources/aws.secret.json](currentDir=".")

// %%
val brRuntime = BedrockRuntimeClient.builder().build().withConfig {
    region = "us-east-1"
    credentialsProvider = kotlinNotebookCredentialProvider
}

// %% [markdown]
// ## Inference via Bedrock Converse API
// Use Bedrock Converse API to inference Nova lite model.

// %%
import aws.sdk.kotlin.services.bedrockruntime.*
import aws.sdk.kotlin.services.bedrockruntime.model.ContentBlock
import aws.sdk.kotlin.services.bedrockruntime.model.ConversationRole
import aws.sdk.kotlin.services.bedrockruntime.model.InferenceConfiguration
import aws.sdk.kotlin.services.bedrockruntime.model.Message
import aws.sdk.kotlin.services.bedrockruntime.model.SystemContentBlock


val response = runBlocking {
    brRuntime.converse {
        inferenceConfig = InferenceConfiguration {
            maxTokens = 100
            temperature = 0f
        }
        modelId = "amazon.nova-lite-v1:0"
        system = listOf(SystemContentBlock.Text("You are Peter, a helpful AI assistant."))
        messages = listOf(
            Message {
                content = listOf(ContentBlock.Text("What is your name and what is your purpose of existence?"))
                role = ConversationRole.User
            }
        )
    }
}

print(response)
// Out:
// ConverseResponse(additionalModelResponseFields=null,metrics=ConverseMetrics(latencyMs=661),output=Message(value=Message(content=[Text(value=Hello! My name is Peter, and I'm here to assist you. My purpose is to provide helpful information, answer your questions, and support you in various tasks you might need help with, whether it's finding information, offering advice, or just having a conversation. How can I assist you today?)],role=Assistant)),performanceConfig=null,stopReason=EndTurn,trace=null,usage=TokenUsage(inputTokens=21,outputTokens=63,totalTokens=84))

// %% [markdown]
// ##  Inference via Bedrock Converse Stream
// Use Bedrock converse stream API to stream Nova lite model response.
// Illustrated how to aggregate the streaming response into final result.

// %%
import aws.sdk.kotlin.services.bedrockruntime.model.ConverseStreamRequest
import kotlinx.coroutines.flow.fold
import kotlinx.coroutines.flow.reduce

runBlocking {
    val result = brRuntime.converseStream(ConverseStreamRequest {
        inferenceConfig = InferenceConfiguration {
            maxTokens = 100
            temperature = 0f
        }
        modelId = "amazon.nova-lite-v1:0"
        system = listOf(SystemContentBlock.Text("You are Peter, a helpful AI assistant."))
        messages = listOf(
            Message {
                content = listOf(ContentBlock.Text("What is your name and what is your purpose of existence?"))
                role = ConversationRole.User
            }
        )
    }) {
        it.stream?.fold("") { acc, e ->
            println(e)
            acc + (e.asContentBlockDeltaOrNull()?.delta?.asTextOrNull() ?: "")
        }
    }

    println("""
    === Aggregated delta text ===
    $result
    """.trimIndent())
}
// Out:
// MessageStart(value=MessageStartEvent(role=Assistant))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=Hello)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=!)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= My)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= name)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= is)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= Peter)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= and)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= I)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=')))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=m)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= here)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= to)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= assist)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= you)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= with)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= a)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= wide)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= range)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= of)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= tasks)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= and)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= questions)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=.)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= My)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= purpose)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= is)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= to)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= provide)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= helpful)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= information)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= answer)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= your)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= queries)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= and)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= support)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= you)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= in)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= various)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= ways)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= whether)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= it)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=')))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=s)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= finding)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= facts)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= offering)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= advice)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=,)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= or)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= helping)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= with)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= creative)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= projects)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=.)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= I)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=')))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=m)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= designed)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= to)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= be)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= a)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= reliable)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= resource)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= to)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= make)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= your)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= life)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= a)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= bit)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= easier)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= and)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= more)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= informed)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=.)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= How)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= can)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= I)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= assist)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= you)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value= today)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=?)))
// ContentBlockDelta(value=ContentBlockDeltaEvent(contentBlockIndex=0,delta=Text(value=)))
// ContentBlockStop(value=ContentBlockStopEvent(contentBlockIndex=0))
// MessageStop(value=MessageStopEvent(additionalModelResponseFields=null,stopReason=EndTurn))
// Metadata(value=ConverseStreamMetadataEvent(metrics=ConverseStreamMetrics(latencyMs=793),performanceConfig=null,trace=null,usage=TokenUsage(inputTokens=21,outputTokens=86,totalTokens=107)))
// === Aggregated delta text ===
// Hello! My name is Peter, and I'm here to assist you with a wide range of tasks and questions. My purpose is to provide helpful information, answer your queries, and support you in various ways, whether it's finding facts, offering advice, or helping with creative projects. I'm designed to be a reliable resource to make your life a bit easier and more informed. How can I assist you today?

// %% [markdown]
// ## Inference with Tool use
// Inference with tool use (functional call).
//
// 1. Process the converse ToolUse response
// 2. Trigger mock getWeatherAPI
// 3. Continue with ToolUseResult

// %%
import aws.sdk.kotlin.services.bedrockruntime.model.*
import aws.smithy.kotlin.runtime.content.Document
import aws.smithy.kotlin.runtime.content.buildDocument

/**
 * Mock API to get weather information
 */
fun getWeatherAPI(date: String, city: String, country: String): Document {
    println("=== calling weather API with date=$date, city=$city, country=$country ===")
    return buildDocument {
        "date" to date
        "city" to city
        "country" to country
        "unit" to "celsius"
        "tempature" to "24"
    }.also {
        println(it)
    }
}

runBlocking {
    var stopReason: StopReason?
    val conversations: MutableList<Message> = mutableListOf()
    do {
        println("=== calling bedrock ===")
        val response = brRuntime.converse {
            inferenceConfig = InferenceConfiguration {
                maxTokens = 1000
                temperature = 0f
            }
            modelId = "amazon.nova-lite-v1:0"
            messages = listOf(
                Message {
                    content = listOf(
                        ContentBlock.Text("What's today wether in Seattle on 2025-01-01?"),
                    )
                    role = ConversationRole.User
                },
                *conversations.toTypedArray()
            )
            toolConfig {
                tools = listOf(Tool.ToolSpec(ToolSpecification {
                    description = "Get weather tool with city, country, and date"
                    name = "GetWeatherTool"
                    inputSchema = ToolInputSchema.Json(
                        buildDocument {
                            "type" to "object"
                            "properties" to buildDocument {
                                "city" to buildDocument {
                                    "type" to "string"
                                    "description" to "City name"
                                    "example" to "San Francisco"
                                }
                                "country" to buildDocument {
                                    "type" to "string"
                                    "description" to "Country code (ISO 3166-1 alpha-2)"
                                    "example" to "US"
                                }
                                "date" to buildDocument {
                                    "type" to "string"
                                    "format" to "date"
                                    "description" to "Date for weather forecast (YYYY-MM-DD)"
                                    "example" to "2024-01-15"
                                }
                            }
                            "required" to buildList {
                                add("city")
                                add("country")
                                add("date")
                            }
                        })
                }))
            }
        }
        println(response)

        stopReason = response.stopReason
        val message = response.output?.asMessageOrNull()
        val toolUseContentBlock = message?.content?.find {
            it is ContentBlock.ToolUse
        }

        if(toolUseContentBlock != null) {
            conversations.add(message)

            val toolUse = toolUseContentBlock.asToolUse()
            val toolUseMap =  toolUse.input?.asMap()
            val date = toolUseMap?.get("date")?.asStringOrNull()
            val city = toolUseMap?.get("city")?.asStringOrNull()
            val country = toolUseMap?.get("country")?.asStringOrNull()
            val _toolUseId = toolUse.toolUseId

            println("=== found ToolUse: $toolUse ===")
            if(date != null && city != null && country != null) {
                ContentBlock.ToolResult(ToolResultBlock {
                    content = listOf(ToolResultContentBlock.Json(
                        getWeatherAPI(date, city, country)
                    ))
                    status = ToolResultStatus.Success
                    toolUseId = _toolUseId
                }).also {
                    conversations.add(Message {
                        content = listOf(it)
                        role = ConversationRole.User
                    })
                }
            }
        }
    } while (stopReason != StopReason.EndTurn)
}
// Out:
// === calling bedrock ===
// ConverseResponse(additionalModelResponseFields=null,metrics=ConverseMetrics(latencyMs=862),output=Message(value=Message(content=[Text(value=<thinking>The User has asked for the weather in Seattle on 2025-01-01. I need to use the GetWeatherTool to retrieve this information. I will call the tool with the provided date, city, and country.</thinking>
// ), ToolUse(value=ToolUseBlock(input={"date":"2025-01-01","country":"US","city":"Seattle"},name=GetWeatherTool,toolUseId=tooluse_Ng_H-fcQQiG9LyqXtQCU9w))],role=Assistant)),performanceConfig=null,stopReason=ToolUse,trace=null,usage=TokenUsage(inputTokens=518,outputTokens=154,totalTokens=672))
// === found ToolUse: ToolUseBlock(input={"date":"2025-01-01","country":"US","city":"Seattle"},name=GetWeatherTool,toolUseId=tooluse_Ng_H-fcQQiG9LyqXtQCU9w) ===
// === calling weather API with date=2025-01-01, city=Seattle, country=US ===
// {"date":"2025-01-01","city":"Seattle","country":"US","unit":"celsius","tempature":"24"}
// === calling bedrock ===
// ConverseResponse(additionalModelResponseFields=null,metrics=ConverseMetrics(latencyMs=791),output=Message(value=Message(content=[Text(value=<thinking>I have retrieved the weather information for Seattle on 2025-01-01 using the GetWeatherTool. The temperature is 24 degrees Celsius. I will now provide this information to the User.</thinking>
//
// The weather in Seattle on 2025-01-01 is expected to be 24 degrees Celsius.)],role=Assistant)),performanceConfig=null,stopReason=EndTurn,trace=null,usage=TokenUsage(inputTokens=675,outputTokens=76,totalTokens=751))
